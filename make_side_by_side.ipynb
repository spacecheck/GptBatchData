# %%
import pandas as pd
import json

# %%
def split_text_on_words(text, max_width):
    """
    Splits a given text into lines with a maximum width, breaking on words.
    """
    words = text.split()
    lines = []
    current_line = []
    current_length = 0

    for word in words:
        if current_length + len(word) + len(current_line) > max_width:
            lines.append(" ".join(current_line))
            current_line = [word]
            current_length = len(word)
        else:
            current_line.append(word)
            current_length += len(word)

    if current_line:
        lines.append(" ".join(current_line))

    return lines

def split_text_on_newlines(text):
    """
    Splits the given text only at new lines.
    """
    return text.splitlines()

def format_text_side_by_side(text1, text2, max_width1, max_width2, spacing):
    """
    Formats two texts side-by-side with given line widths and spacing.
    """
    lines1 = split_text_on_words(text1, max_width1)
    lines2 = split_text_on_newlines(text2)
    formatted_lines = []

    max_lines = max(len(lines1), len(lines2))
    lines1.extend([""] * (max_lines - len(lines1)))
    lines2.extend([""] * (max_lines - len(lines2)))

    for line1, line2 in zip(lines1, lines2):
        formatted_lines.append(
            f"{line1.ljust(max_width1)}{' ' * spacing}{line2.ljust(max_width2)}"
        )

    return "\n".join(formatted_lines)

# %%
input_data = pd.read_csv("data.csv")
gpt_out = pd.read_csv("output.csv")

for idx, row in gpt_out.iterrows():
    id = row["id"]
    schema = row["content"]
    schema = json.loads(schema)
    text2 = json.dumps(schema, indent=4)
    text1 = input_data[input_data["id"] == id]["text"].values[0]

    formatted_output = format_text_side_by_side(text1, text2, 60, 80, 10)
    print(formatted_output)
    print("_"*120)
    #break
# Out:
# Preheat oven to 400 degrees F (205 degrees C). Grease                 {
# interior of 8 inch springform pan and dust lightly with                   "pretentious_recipy_name": "Ethereal Cloud of Passion",
# cornstarch. Beat egg whites, preferably in a glass or                     "is_vegan": false,
# ceramic bowl, until stiff and glossy. Make sure egg whites                "oven_instructions": {
# have absolutely no contact with grease (fresh or residual),                   "preheat_temperature_celcius": 205,
# or even a speck of yolk. Combine cream of tartar, white                       "time_in_oven_minutes": 90
# sugar, and cornstarch; gradually beat in to the egg whites.               },
# Sprinkle vinegar over egg white mixture, then fold it in                  "recipe_type": "dessert",
# very gently. Pile meringue into prepared pan. Spread to the               "necessary_utensils": [
# sides leaving a slight depression in the center. Place in                     "oven",
# preheated oven. Close the oven door, and immediately turn                     "springform_pan",
# oven down to 250 degrees F (120 degrees C). Bake for 75 to                    "bowl",
# 90 minutes. Open oven door, but leave meringue in the oven                    "serving_platter"
# for 15 more minutes. Remove meringue to a draft free spot.                ]
# Very carefully remove rim of springform pan, and allow                }
# meringue to cool completely. There may be a slight sinking
# in the center. Carefully remove meringue from pan base, and
# place on serving platter. Whip cream, vanilla extract, and
# confectioners' sugar until thick and firm. Gently spread
# over the meringue. Remove the pulp from the passion fruit,
# and spoon over cream. If using kiwi, peel and slice the
# fruit; arrange slightly overlapping slices in a pleasing
# design. Chill until serving time.
# ________________________________________________________________________________________________________________________
# Preheat the oven to 375 degrees F (190 degrees C). Place              {
# sliced apples in a large bowl; sprinkle with lemon juice.                 "pretentious_recipy_name": "Rustic Autumnal Orchard Delight",
# Mix white sugar, 2 tablespoons flour, cinnamon, and nutmeg                "is_vegan": false,
# together in a small bowl; sprinkle mixture over apples and                "oven_instructions": {
# toss until evenly coated. Stir in raisins and walnuts;                        "preheat_temperature_celcius": 190,
# transfer mixture into pie shell. Mix 1/2 cup flour and brown                  "time_in_oven_minutes": 55
# sugar together in a small bowl. Blend in butter with a fork               },
# until mixture is crumbly; sprinkle over apple filling. Cover              "recipe_type": "dessert",
# top of pie loosely with aluminum foil. Bake in the preheated              "necessary_utensils": [
# oven for 25 minutes. Remove foil and bake until top is                        "oven",
# golden brown and filling is bubbly, about 25 to 30 minutes                    "bowl",
# more. Cool on a wire rack before serving.                                     "pie_shell",
#                                                                               "aluminum_foil",
#                                                                               "wire_rack"
#                                                                           ]
#                                                                       }
# ________________________________________________________________________________________________________________________
# Preheat the oven to 375 degrees F (190 degrees C). Grease a           {
# 12-cup muffin pan. Mix flour, baking powder, baking soda,                 "pretentious_recipy_name": "Artisanal Apple Infused Muffin Medley",
# and salt in a medium bowl. Beat together sugar, butter, and               "is_vegan": false,
# eggs in a large bowl until smooth. Mix in vanilla. Stir in                "oven_instructions": {
# apples, then gradually blend in flour mixture. Spoon batter                   "preheat_temperature_celcius": 190,
# into the prepared muffin pan. Make topping: Mix brown sugar,                  "time_in_oven_minutes": 20
# flour, and cinnamon in a small bowl. Cut in butter until                  },
# mixture resembles coarse crumbs. Sprinkle over each muffin                "recipe_type": "dessert",
# top. Bake in the preheated oven until a toothpick inserted                "necessary_utensils": [
# in the center of a muffin comes out clean, about 20 minutes.                  "oven",
# Let sit 5 minutes before transferring muffins to a wire rack                  "muffin_pan",
# to cool.                                                                      "bowl",
#                                                                               "wire_rack"
#                                                                           ]
#                                                                       }
# ________________________________________________________________________________________________________________________
# Preheat the oven to 325 degrees F (165 degrees C). Grease a           {
# 9x5-inch loaf pan, preferably glass. Mix flour, baking                    "pretentious_recipy_name": "Banana Symphony in a Glass Loaf",
# powder, baking soda, and salt in a bowl. Stir bananas, milk,              "is_vegan": false,
# and cinnamon in another bowl. Beat sugar and butter together              "oven_instructions": {
# in a third bowl with an electric mixer until light and                        "preheat_temperature_celcius": 165,
# fluffy; add eggs one at a time, beating well after each                       "time_in_oven_minutes": 70
# addition. Stir banana mixture into butter mixture; mix in                 },
# flour mixture until just blended. Fold in chocolate chips;                "recipe_type": "dessert",
# pour batter into the prepared loaf pan. Bake in the                       "necessary_utensils": [
# preheated oven until a toothpick inserted into the center                     "oven",
# comes out clean, about 70 minutes. Cool in the pan for 10                     "loaf_pan",
# minutes before removing to cool completely on a wire rack                     "bowl",
# before slicing.                                                               "electric_mixer",
#                                                                               "wire_rack"
#                                                                           ]
#                                                                       }
# ________________________________________________________________________________________________________________________
# Preheat an oven to 350 degrees F (175 degrees C). Lightly             {
# oil a 9x13-inch baking dish. Mix the eggs, banana, oats,                  "pretentious_recipy_name": "Artisanal Sunrise Oat Bars with a Symphony of Nature's Bounty",
# sunflower seeds, cinnamon, milk powder, dates, raisins,                   "is_vegan": false,
# walnuts, apricots, wheat germ, maple syrup, and whole-wheat               "oven_instructions": {
# pastry flour together in a large bowl until thoroughly                        "preheat_temperature_celcius": 175,
# combined; spread the mixture evenly into the prepared baking                  "time_in_oven_minutes": 20
# dish. Bake in the preheated oven for 20 minutes; set aside                },
# to cool. Cut into 9 bars and wrap with plastic to store.                  "recipe_type": "dessert",
#                                                                           "necessary_utensils": [
#                                                                               "oven",
#                                                                               "baking_dish",
#                                                                               "mixing_bowl"
#                                                                           ]
#                                                                       }
# ________________________________________________________________________________________________________________________
# Preheat oven to 350 degrees F (175 degrees C). Grease the             {
# bottom of a 5x9-inch loaf pan. Beat white sugar and butter                "pretentious_recipy_name": "Decadent Symphony of Banana-Peach Harmony",
# together in a large bowl with an electric mixer until light               "is_vegan": false,
# and fluffy. Add brown sugar and hot chocolate mix; stir                   "oven_instructions": {
# well. Place bananas, peach, milk, eggs, and vanilla extract                   "preheat_temperature_celcius": 175,
# in a blender; blend until smooth. Stir into butter mixture                    "time_in_oven_minutes": 55
# until well incorporated. Mix flour, walnuts, baking soda,                 },
# and salt together in a separate bowl; stir into                           "recipe_type": "dessert",
# banana-butter mixture until flour mixture is just moistened.              "necessary_utensils": [
# Pour batter into the prepared loaf pan. Bake in the                           "oven",
# preheated oven until a toothpick inserted in the center of                    "loaf_pan",
# bread comes out clean, 50 to 60 minutes. Cool in pan for 5                    "blender",
# minutes before transferring bread to a wire rack to cool                      "bowl",
# completely.                                                                   "electric_mixer",
#                                                                               "wire_rack"
#                                                                           ]
#                                                                       }
# ________________________________________________________________________________________________________________________
# Combine mango and pineapple juice in a blender; blend until           {
# smooth. Set aside. Rub lime wedge around the rim of a glass,              "pretentious_recipy_name": "Tropical Elixir of the Sun-Kissed Isles",
# then dip in 1 teaspoon chili-lime seasoning. Juice lime into              "is_vegan": true,
# the glass; add 1 tablespoon chamoy and remaining 1 teaspoon               "oven_instructions": null,
# chili-lime seasoning. Pour 1/2 of the mango-pineapple                     "recipe_type": "drink",
# mixture into the prepared glass. Add remaining 1 tablespoon               "necessary_utensils": [
# chamoy sauce and top with remaining mango-pineapple mixture.                  "blender",
#                                                                               "glass"
#                                                                           ]
#                                                                       }
# ________________________________________________________________________________________________________________________
# Heat a skillet over medium-high heat. Sear pork chops in the          {
# hot skillet until lightly browned, about 1 minute per side.               "pretentious_recipy_name": "Autumnal Porcine Symphony with a Cranberry-Fig Reduction",
# Transfer seared pork chops to the slow cooker. Combine                    "is_vegan": false,
# cranberries, figs, reserved fig juice, apple juice, brown                 "oven_instructions": null,
# sugar, salt, black pepper, and rosemary in a saucepan; bring              "recipe_type": "main_course",
# to a boil. Pour cranberry mixture over pork chops. Cook on                "necessary_utensils": [
# High for 4 hours.                                                             "skillet",
#                                                                               "slow_cooker",
#                                                                               "saucepan"
#                                                                           ]
#                                                                       }
# ________________________________________________________________________________________________________________________
# Combine apple cider and cinnamon sticks in a slow cooker.             {
# Place allspice and cloves onto the center of an 8-inch                    "pretentious_recipy_name": "Autumnal Elixir of Spiced Orchard Essence",
# square piece of cheesecloth. Gather edges of the cheesecloth              "is_vegan": true,
# together and tie to secure; place in the slow cooker. Stir                "oven_instructions": null,
# in brown sugar. Cook on High until it comes to a boil.                    "recipe_type": "drink",
# Reduce heat to Low and keep warm.                                         "necessary_utensils": [
#                                                                               "slow_cooker",
#                                                                               "cheesecloth"
#                                                                           ]
#                                                                       }
# ________________________________________________________________________________________________________________________
# Stir mango, rice vinegar, lime juice, Thai chile pepper,              {
# garlic, and hot chile paste in a bowl until well combined.                "pretentious_recipy_name": "Tropical Zest Infusion with a Fiery Embrace",
# Cover and let rest 30 minutes. Stir in cilantro.                          "is_vegan": true,
#                                                                           "oven_instructions": null,
#                                                                           "recipe_type": "salad",
#                                                                           "necessary_utensils": [
#                                                                               "bowl"
#                                                                           ]
#                                                                       }
# ________________________________________________________________________________________________________________________
# Slice strawberries and sprinkle them with sugar. Cut the              {
# bananas into slices and toss with orange juice. Combine                   "pretentious_recipy_name": "Layered Symphony of Fruity Elegance",
# pudding mix with milk and mix until smooth. Cut the cake                  "is_vegan": false,
# into 1 inch cubes. Use half of the cake cubes to line the                 "oven_instructions": null,
# bottom of a large glass bowl. Layer half of the strawberries              "recipe_type": "dessert",
# followed by half of the blueberries, and then half of the                 "necessary_utensils": [
# bananas. Spread half of the pudding over the fruit. Repeat                    "bowl",
# layers in the same order. In a medium bowl, whip the cream                    "mixing_bowl",
# to stiff peaks and spread over top of trifle. Garnish with                    "glass"
# maraschino cherries and slivered almonds.                                 ]
#                                                                       }
# ________________________________________________________________________________________________________________________
# In a medium mixing bowl, beat together softened cream cheese          {
# and sugar until light and fluffy. Fold in whipped topping                 "pretentious_recipy_name": "Decadent Cloud of Creamy Delight",
# and blend until mixture is smooth. Spread into graham                     "is_vegan": false,
# cracker crust and spoon pie filling over top. Cover with                  "oven_instructions": null,
# plastic wrap and chill 2 hours before serving.                            "recipe_type": "dessert",
#                                                                           "necessary_utensils": [
#                                                                               "mixing_bowl"
#                                                                           ]
#                                                                       }
# ________________________________________________________________________________________________________________________
# Blend milk, papaya, sugar, vanilla extract, and cinnamon              {
# together in a blender until smooth; add ice and blend until               "pretentious_recipy_name": "Papaya Elixir of the Tropics",
# slushy.                                                                   "is_vegan": false,
#                                                                           "oven_instructions": null,
#                                                                           "recipe_type": "drink",
#                                                                           "necessary_utensils": [
#                                                                               "blender"
#                                                                           ]
#                                                                       }
# ________________________________________________________________________________________________________________________
# Combine hot water, sugar, and powdered gelatin in a small             {
# bowl; stir until sugar and gelatin are dissolved. Mix mango               "pretentious_recipy_name": "Tropical Mango Ambrosia Delight",
# pulp, evaporated milk, and cold water together in a large                 "is_vegan": false,
# bowl. Pour in hot water mixture and stir well. Refrigerate                "oven_instructions": null,
# until set, at least 4 hours.                                              "recipe_type": "dessert",
#                                                                           "necessary_utensils": [
#                                                                               "bowl",
#                                                                               "mixing_bowl"
#                                                                           ]
#                                                                       }
# ________________________________________________________________________________________________________________________
# Whisk vinegar, pomegranate juice, shallot, pepper, and white          {
# sugar together in a bowl until sugar dissolves. Add                       "pretentious_recipy_name": "Chilled Ambrosia of the Pomaceous Realm",
# pomegranate seeds, cover the bowl with plastic wrap, and                  "is_vegan": true,
# refrigerate until chilled, about 1 hour.                                  "oven_instructions": null,
#                                                                           "recipe_type": "salad",
#                                                                           "necessary_utensils": [
#                                                                               "bowl",
#                                                                               "whisk"
#                                                                           ]
#                                                                       }
# ________________________________________________________________________________________________________________________
# Gently toss watermelon, onion, basil, cilantro, mint, lime            {
# juice, feta cheese, olive oil, balsamic vinegar, salt, and                "pretentious_recipy_name": "Ethereal Symphony of Summer's Bounty",
# black pepper together in a large bowl.                                    "is_vegan": false,
#                                                                           "oven_instructions": null,
#                                                                           "recipe_type": "salad",
#                                                                           "necessary_utensils": [
#                                                                               "bowl"
#                                                                           ]
#                                                                       }
# ________________________________________________________________________________________________________________________
# Preheat oven to 350 degrees F (175 degrees C). Grease and             {
# flour an 7x11-inch baking dish. Beat 1/2 cup sugar and 2                  "pretentious_recipy_name": "Plum Perfection in a Crumbly Cloud",
# tablespoons margarine together in a bowl using an electric                "is_vegan": false,
# mixer until smooth and creamy. Mix eggs, 1 cup flour, baking              "oven_instructions": {
# powder, and salt into creamed margarine mixture; stir in                      "preheat_temperature_celcius": 175,
# vanilla. Pour batter into the prepared baking dish. Arrange                   "time_in_oven_minutes": 35
# plums, skin side-down, atop batter. Mix 1 cup sugar, 1/2 cup              },
# flour, 3 tablespoons margarine, and cinnamon together in a                "recipe_type": "dessert",
# bowl until crumbly; spoon over batter and plums. Bake in the              "necessary_utensils": [
# preheated oven until plums are softened, about 35 minutes.                    "oven",
#                                                                               "baking_dish",
#                                                                               "bowl",
#                                                                               "electric_mixer"
#                                                                           ]
#                                                                       }
# ________________________________________________________________________________________________________________________
# Preheat oven to 325 degrees F (165 degrees C). Grease and             {
# flour a 10 inch tube pan. Mix together the flour, baking                  "pretentious_recipy_name": "Ethereal Symphony of Flavors Cake",
# soda and salt. Set aside. Combine the sour cream, rum                     "is_vegan": false,
# flavoring, orange extract, almond extract, lemon extract,                 "oven_instructions": {
# vanilla extract and apricot brandy. Set aside. In a large                     "preheat_temperature_celcius": 165,
# bowl, cream together the butter and sugar until light and                     "time_in_oven_minutes": 60
# fluffy. Beat in the eggs one at a time. Beat in the flour                 },
# mixture alternately with the sour cream and flavorings                    "recipe_type": "dessert",
# mixture, stirring just until incorporated. Pour batter into               "necessary_utensils": [
# prepared pan. Bake in the preheated oven for 60 minutes, or                   "oven",
# until a toothpick inserted into the center of the cake comes                  "tube_pan",
# out clean. Allow to cool.                                                     "bowl",
#                                                                               "mixing_bowl"
#                                                                           ]
#                                                                       }
# ________________________________________________________________________________________________________________________
# Preheat oven to 325 degrees F (165 degrees C). Butter a 10            {
# inch tube pan and coat with white sugar. In a large bowl,                 "pretentious_recipy_name": "Ethereal Peach Symphony in a Sugary Embrace",
# cream together the butter and sugar until light and fluffy.               "is_vegan": false,
# Add the eggs one at a time, beating well with each addition,              "oven_instructions": {
# then stir in the vanilla. Reserve 1/4 cup of flour for                        "preheat_temperature_celcius": 165,
# later, and sift together the remaining flour, baking powder                   "time_in_oven_minutes": 65
# and salt. Gradually stir into the creamed mixture. Use the                },
# reserved flour to coat the chopped peaches, then fold the                 "recipe_type": "dessert",
# floured peaches into the batter. Spread evenly into the                   "necessary_utensils": [
# prepared pan. Bake for 60 to 70 minutes in the preheated                      "oven",
# oven, or until a toothpick inserted into the cake comes out                   "tube_pan",
# clean. Allow cake to cool in the pan for 10 minutes, before                   "bowl",
# inverting onto a wire rack to cool completely.                                "wire_rack"
#                                                                           ]
#                                                                       }
# ________________________________________________________________________________________________________________________
# Combine the lemon and 4 cups water in a large bowl. Place             {
# the sliced apples in the water to keep them from browning.                "pretentious_recipy_name": "Artisanal Apple Turnovers with a Zesty Citrus Prelude",
# Melt butter in a large skillet over medium heat. Drain water              "is_vegan": false,
# from apples, and place them into the hot skillet. Cook and                "oven_instructions": {
# stir for about 2 minutes. Add brown sugar, and cinnamon, and                  "preheat_temperature_celcius": 200,
# cook, stirring, for 2 more minutes. Stir together cornstarch                  "time_in_oven_minutes": 25
# and 1 tablespoon water. Pour into the skillet, and mix well.              },
# Cook for another minute, or until sauce has thickened.                    "recipe_type": "dessert",
# Remove from heat to cool slightly. Preheat the oven to 400                "necessary_utensils": [
# degrees F (200 degrees C). Unfold puff pastry sheets, and                     "bowl",
# repair any cracks by pressing them back together. Trim each                   "skillet",
# sheet into a square. Then cut each larger square into 4                       "baking_sheet",
# smaller squares. Spoon apples onto the center of each                         "mixing_bowl"
# squares. Fold over from corner to corner into a triangle                  ]
# shape, and press edges together to seal. Place turnovers on           }
# a baking sheet, leaving about 1 inch between them. Bake for
# 25 minutes in the preheated oven, until turnovers are puffed
# and lightly browned. Cool completely before glazing. To make
# the glaze, mix together the confectioners' sugar, milk and
# vanilla in a small bowl. Adjust the thickness by adding more
# sugar or milk if necessary. Drizzle glaze over the cooled
# turnovers.
# ________________________________________________________________________________________________________________________
